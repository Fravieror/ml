# %%
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 20, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 20.026829225979647

# %%
incomes.var()
# Out:
# 401.07388884655256
